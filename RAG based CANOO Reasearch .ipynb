# %%
#Initializing api keys
import os
os.environ['LANGCHAIN_TRACING_V2'] = 'true'
os.environ['LANGCHAIN_ENDPOINT'] = 'https://api.smith.langchain.com'
os.environ['LANGCHAIN_API_KEY'] = 'ls__86e2989fd1ca4614ab1e747ef2d18332'
os.environ['OPENAI_API_KEY'] = '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'

# %%
# scrap openinternet to find weblinks with google query 'Industry_in_which_Canoo_operates'
import csv
import requests
from bs4 import BeautifulSoup 
import urllib.parse

def google_search(query, num_pages=16):
    links = []
    for page in range(num_pages):
        start_index = page * 10
        search_url = f"https://www.google.com/search?q={query}&start={start_index}"
        response = requests.get(search_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        # Extract URLs from search results
        for a in soup.find_all('a', href=True):
            if 'url?q=' in a['href']:
                link = a['href'].split('url?q=')[1].split('&sa=U&')[0]
                if link.startswith('http'):
                    if not any(substring in link for substring in ['maps.google.com', 'accounts.google.com', 'support.google.com']):
                        links.append(link)
    # Write links to CSV file
    with open('Industry_in_which_Canoo_operates.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([ 'URL'])
        for link in links:
            writer.writerow([link])
    
    return links

# Perform Google search for a specific query with 15 pages of results
query = "Identify the industry in which Canoo(GOEV) operates, along with its size, growth rate, trends, and key players."
search_results = google_search(query, num_pages=16  )  # For debugging, let's just scrape the first page

print(search_results)  # Print the scraped links for debugging purposes
# Out:
# ['https://investors.canoo.com/', 'https://en.wikipedia.org/wiki/Canoo', 'https://www.press.canoo.com/press-release/mpdv', 'https://www.canoo.com/about/', 'https://www.press.canoo.com/press-release/zeeba', 'https://investors.canoo.com/sec-filings/all-sec-filings/content/0001628280-22-004514/goev-20211231.htm', 'https://corporate.walmart.com/news/2022/07/12/walmart-to-purchase-4-500-canoo-electric-delivery-vehicles-to-be-used-for-last-mile-deliveries-in-support-of-its-growing-ecommerce-business', 'https://29b2eb86d7.clvaw-cdnwnd.com/18b93d4bb4f77ddec8c75f8adc4f29dc/200001185-d3b5ed3b61/Internship_Assignment_Coding2024.pdf%3Fph%3D29b2eb86d7', 'https://www.press.canoo.com/press-release/merger-announcement', 'https://www.industryweek.com/leadership/companies-executives/article/21263239/canoo-sticks-to-2023-production-target', 'https://www.quora.com/Is-Canoo-GOEV-stock-undervalued', 'https://investors.canoo.com/news-presentations/press-releases/detail/121/canoo-acquires-manufacturing-asset
# ...

# %%
# scrap openinternet to find weblinks with google query 'Canoo main competitors'
import csv
import requests
from bs4 import BeautifulSoup 
import urllib.parse

def google_search(query, num_pages=16):
    links = []
    for page in range(num_pages):
        start_index = page * 10
        search_url = f"https://www.google.com/search?q={query}&start={start_index}"
        response = requests.get(search_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        # Extract URLs from search results
        for a in soup.find_all('a', href=True):
            if 'url?q=' in a['href']:
                link = a['href'].split('url?q=')[1].split('&sa=U&')[0]
                if link.startswith('http'):
                    if not any(substring in link for substring in ['maps.google.com', 'accounts.google.com', 'support.google.com']):
                        links.append(link)
    # Write links to CSV file
    with open('Canoo main competitors.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([ 'URL'])
        for link in links:
            writer.writerow([link])
    
    return links

# Perform Google search for a specific query with 15 pages of results
query = "Analyze Canoo's main competitors, including their market share, products or services offered, pricing strategies, and marketing efforts"
search_results = google_search(query, num_pages=16  )  # For debugging, let's just scrape the first page

print(search_results)  # Print the scraped links for debugging purposes
# Out:
# ['https://dcf.fm/blogs/blog/goev-marketing-mix', 'https://dcf.fm/blogs/blog/goev-porters-five-forces-analysis', 'https://www.lizmotors.com/internship-coding-assignment2024/', 'https://finpedia.co/bin/Canoo%2520Inc./', 'https://in.marketscreener.com/quote/stock/CANOO-INC-57291647/news/CANOO-INC-MANAGEMENT-S-DISCUSSION-AND-ANALYSIS-OF-FINANCIAL-CONDITION-AND-RESULTS-OF-OPERATIONS-f-43386654/', 'https://29b2eb86d7.clvaw-cdnwnd.com/18b93d4bb4f77ddec8c75f8adc4f29dc/200001185-d3b5ed3b61/Internship_Assignment_Coding2024.pdf%3Fph%3D29b2eb86d7', 'https://fortune.com/2022/08/29/canoo-ev-startup-scored-deal-worlds-largest-retailer/', 'https://www.sec.gov/Archives/edgar/data/1750153/000121390023011578/ea173431ex99-1_canooinc.htm', 'https://investors.canoo.com/sec-filings/all-sec-filings/content/0001628280-22-004514/goev-20211231.htm', 'https://investors.canoo.com/sec-filings/all-sec-filings/content/0001628280-23-009932/goev-20221231.htm', 'https://www.macroaxis.com/invest/ratio/GOEV/Five-Year-Re
# ...

# %%
## scrap openinternet to find weblinks with google query'Key trends in the market'
import csv
import requests
from bs4 import BeautifulSoup 
import urllib.parse

def google_search(query, num_pages=16):
    links = []
    for page in range(num_pages):
        start_index = page * 10
        search_url = f"https://www.google.com/search?q={query}&start={start_index}"
        response = requests.get(search_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        # Extract URLs from search results
        for a in soup.find_all('a', href=True):
            if 'url?q=' in a['href']:
                link = a['href'].split('url?q=')[1].split('&sa=U&')[0]
                if link.startswith('http'):
                    if not any(substring in link for substring in ['maps.google.com', 'accounts.google.com', 'support.google.com']):
                        links.append(link)

    # Write links to CSV file
    with open('Key trends in the market.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([ 'URL'])
        for link in links:
            writer.writerow([link])
    
    return links

# Perform Google search for a specific query with 15 pages of results
query = "Identify key trends in the market, including changes in consumer behavior, technological advancements, and shifts in the competitive landscape."
search_results = google_search(query, num_pages=16  )  # For debugging, let's just scrape the first page

print(search_results)  # Print the scraped links for debugging purposes
# Out:
# ['https://www.linkedin.com/pulse/evolution-consumer-behavior-marketing-trends-stay-ahead', 'https://www.mikevestil.com/market-trends/', 'https://fastercapital.com/startup-topic/trends-and-changes-in-consumer.html', 'https://www.thekeenfolks.com/blog-article/the-impact-of-technology-on-consumer-behaviour', 'https://www.market-xcel.com/blogs/navigating-the-shifting-tides-consumer-behaviour-trends', 'https://alistemarketing.com/blog/identifying-trends-in-consumer-buying-behavior-understanding-the-shifting-demands-of-modern-consumers/', 'https://growthnatives.com/blogs/digital-marketing/what-are-the-key-marketing-trends/', 'https://fastercapital.com/content/Consumer-behavior--Understanding-Industry-Trends-through-Consumer-Behavior-Patterns.html', 'https://www.quora.com/What-are-the-key-trends-and-consumer-preferences-in-our-industry-and-how-can-we-adapt-our-products-or-services-to-meet-these-changing-demands', 'https://www.researchgate.net/publication/374436215_Technological_Innovation_i
# ...

# %%
# scrap openinternet to find weblinks with google query'Information on Canoo ﬁnancial'
import csv
import requests
from bs4 import BeautifulSoup 
import urllib.parse

def google_search(query, num_pages=16):
    links = []
    for page in range(num_pages):
        start_index = page * 10
        search_url = f"https://www.google.com/search?q={query}&start={start_index}"
        response = requests.get(search_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        # Extract URLs from search results
        for a in soup.find_all('a', href=True):
            if 'url?q=' in a['href']:
                link = a['href'].split('url?q=')[1].split('&sa=U&')[0]
                if link.startswith('http'):
                    if not any(substring in link for substring in ['maps.google.com', 'accounts.google.com', 'support.google.com']):
                        links.append(link)
    # Write links to CSV file
    with open('Information on Canoo ﬁnancial.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([ 'URL'])
        for link in links:
            writer.writerow([link])
    
    return links

# Perform Google search for a specific query with 15 pages of results
query = "Canoo's ﬁnancial performance its revenue, proﬁt margins, return on investment, and expense structure. "
search_results = google_search(query, num_pages=16  )  # For debugging, let's just scrape the first page

print(search_results)  # Print the scraped links for debugging purposes
# Out:
# ['https://in.marketscreener.com/quote/stock/CANOO-INC-57291647/news/CANOO-INC-MANAGEMENT-S-DISCUSSION-AND-ANALYSIS-OF-FINANCIAL-CONDITION-AND-RESULTS-OF-OPERATIONS-f-43386654/', 'https://investors.canoo.com/sec-filings/all-sec-filings/content/0001628280-23-009932/0001628280-23-009932.pdf', 'https://in.investing.com/equities/hennessy-capital-acquisition-corp-financial-summary', 'https://finpedia.co/bin/Canoo%2520Inc./', 'https://www.wsj.com/market-data/quotes/GOEV/financials', 'https://www.sec.gov/Archives/edgar/data/1750153/000121390021001996/fs12021_canooinc.htm', 'https://investors.canoo.com/financial-information/income-statement', 'https://www.macroaxis.com/invest/bond/GOEV', 'https://www.prnewswire.com/news-releases/canoo-inc-announces-first-quarter-2023-results-301825198.html', 'https://simplywall.st/stocks/us/automobiles/nasdaq-goev/canoo/past', 'https://www.sec.gov/Archives/edgar/data/1750153/000121390023011578/ea173431ex99-1_canooinc.htm', 'https://seekingalpha.com/article/46
# ...

# %%
#script scraps the collected links to get website date by identifying tags to parsed html text and store it in csv file
import pandas as pd
import requests
from bs4 import BeautifulSoup
import PyPDF2
import io

# Function to scrape content from a URL
def scrape_content(url):
    try:
        # Check if the URL is a PDF
        if url.endswith('.pdf'):
            # Handle PDF content
            return extract_pdf_content(url)
        
        # Send a GET request to the URL
        response = requests.get(url)
        # Check if the request was successful
        response.raise_for_status()
        # Parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        # Find and extract the main body content (you might need to adjust this based on the structure of your HTML)
        main_content = soup.find('<h1>,<h2>,<h3>,<h4>,<h5>,<h6>,<table>,<p>')
        return main_content
    except requests.exceptions.RequestException as e:
        print(f"Error scraping {url}: {e}")
        return None
    except Exception as e:
        print(f"Unexpected error scraping {url}: {e}")
        return None
# Function to extract content from a PDF and convert it to CSV
def extract_pdf_content(url):
    try:
        # Send a GET request to the PDF URL
        response = requests.get(url)
        # Check if the request was successful
        response.raise_for_status()
        
        # Parse the PDF content
        with io.BytesIO(response.content) as pdf_file:
            pdf_reader = PyPDF2.PdfReader(pdf_file)
            num_pages = len(pdf_reader.pages)
            text = ""
            for page_num in range(num_pages):
                page = pdf_reader.pages[page_num]
                text += page.extract_text()
        
        # For demonstration purposes, let's just return the extracted text
        return text
    except requests.exceptions.RequestException as e:
        print(f"Error downloading PDF from {url}: {e}")
        return None
    except Exception as e:
        print(f"Error extracting content from PDF {url}: {e}")
        return None

# Read the CSV file containing links
input_file = "Industry_in_which_Canoo_operates.csv"
output_file = "Industry_in_which_Canoo_operates_data.csv"
data = pd.read_csv(input_file)

# Create an empty list to store scraped content
scraped_content = []

# Iterate through each link in the CSV file and scrape its content
for link in data['URL']:
    content = scrape_content(link)
    scraped_content.append(content)

# Add the scraped content to the DataFrame
data['Scraped Content'] = scraped_content

# Write the DataFrame with scraped content to a new CSV file
data.to_csv(output_file, index=False)

print("Scraping and saving completed!")
# Out:
# Error scraping https://29b2eb86d7.clvaw-cdnwnd.com/18b93d4bb4f77ddec8c75f8adc4f29dc/200001185-d3b5ed3b61/Internship_Assignment_Coding2024.pdf%3Fph%3D29b2eb86d7: 403 Client Error: Forbidden for url: https://29b2eb86d7.clvaw-cdnwnd.com/18b93d4bb4f77ddec8c75f8adc4f29dc/200001185-d3b5ed3b61/Internship_Assignment_Coding2024.pdf%3Fph%3D29b2eb86d7
# Error downloading PDF from https://www.nrc.gov/docs/ML0907/ML090710600.pdf: 403 Client Error: Forbidden for url: https://www.nrc.gov/docs/ML0907/ML090710600.pdf
# Error scraping https://www.sec.gov/Archives/edgar/data/1750153/000121390020039415/fs42020a2_hennessycapacqiv.htm: 403 Client Error: Forbidden for url: https://www.sec.gov/Archives/edgar/data/1750153/000121390020039415/fs42020a2_hennessycapacqiv.htm
# Error scraping https://www.sciencedirect.com/science/article/pii/S1755008421000600: 403 Client Error: Forbidden for url: https://www.sciencedirect.com/science/article/pii/S1755008421000600
# ...

# %%
#script scraps the collected links to get website date by identifying tags to parsed html text and store it in csv file
import pandas as pd
import requests
from bs4 import BeautifulSoup
import PyPDF2
import io

# Function to scrape content from a URL
def scrape_content(url):
    try:
        # Check if the URL is a PDF
        if url.endswith('.pdf'):
            # Handle PDF content
            return extract_pdf_content(url)
        
        # Send a GET request to the URL
        response = requests.get(url)
        # Check if the request was successful
        response.raise_for_status()
        # Parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        # Find and extract the main body content (you might need to adjust this based on the structure of your HTML)
        main_content = soup.find('<h1>,<h2>,<h3>,<h4>,<h5>,<h6>,<table>,<p>,<p class>,<p style>')
        return main_content
    except requests.exceptions.RequestException as e:
        print(f"Error scraping {url}: {e}")
        return None
    except Exception as e:
        print(f"Unexpected error scraping {url}: {e}")
        return None
# Function to extract content from a PDF and convert it to CSV
def extract_pdf_content(url):
    try:
        # Send a GET request to the PDF URL
        response = requests.get(url)
        # Check if the request was successful
        response.raise_for_status()
        
        # Parse the PDF content
        with io.BytesIO(response.content) as pdf_file:
            pdf_reader = PyPDF2.PdfReader(pdf_file)
            num_pages = len(pdf_reader.pages)
            text = ""
            for page_num in range(num_pages):
                page = pdf_reader.pages[page_num]
                text += page.extract_text()
        
        # For demonstration purposes, let's just return the extracted text
        return text
    except requests.exceptions.RequestException as e:
        print(f"Error downloading PDF from {url}: {e}")
        return None
    except Exception as e:
        print(f"Error extracting content from PDF {url}: {e}")
        return None

# Read the CSV file containing links
input_file = "Canoo main competitors.csv"
output_file = "Canoo main competitors data.csv"
data = pd.read_csv(input_file)

# Create an empty list to store scraped content
scraped_content = []

# Iterate through each link in the CSV file and scrape its content
for link in data['URL']:
    content = scrape_content(link)
    scraped_content.append(content)

# Add the scraped content to the DataFrame
data['Scraped Content'] = scraped_content

# Write the DataFrame with scraped content to a new CSV file
data.to_csv(output_file, index=False)

print("Scraping and saving completed!")
# Out:
# Error scraping https://finpedia.co/bin/Canoo%2520Inc./: 404 Client Error: Not Found for url: https://finpedia.co/bin/Canoo%2520Inc./
# Error scraping https://in.marketscreener.com/quote/stock/CANOO-INC-57291647/news/CANOO-INC-MANAGEMENT-S-DISCUSSION-AND-ANALYSIS-OF-FINANCIAL-CONDITION-AND-RESULTS-OF-OPERATIONS-f-43386654/: 403 Client Error: Forbidden. for url: https://in.marketscreener.com/quote/stock/CANOO-INC-57291647/news/CANOO-INC-MANAGEMENT-S-DISCUSSION-AND-ANALYSIS-OF-FINANCIAL-CONDITION-AND-RESULTS-OF-OPERATIONS-f-43386654/
# Error scraping https://29b2eb86d7.clvaw-cdnwnd.com/18b93d4bb4f77ddec8c75f8adc4f29dc/200001185-d3b5ed3b61/Internship_Assignment_Coding2024.pdf%3Fph%3D29b2eb86d7: 403 Client Error: Forbidden for url: https://29b2eb86d7.clvaw-cdnwnd.com/18b93d4bb4f77ddec8c75f8adc4f29dc/200001185-d3b5ed3b61/Internship_Assignment_Coding2024.pdf%3Fph%3D29b2eb86d7
# ...

# %%
#script scraps the collected links to get website date by identifying tags to parsed html text and store it in csv file
import pandas as pd
import requests
from bs4 import BeautifulSoup
import PyPDF2
import io

# Function to scrape content from a URL
def scrape_content(url):
    try:
        # Check if the URL is a PDF
        if url.endswith('.pdf'):
            # Handle PDF content
            return extract_pdf_content(url)
        
        # Send a GET request to the URL
        response = requests.get(url)
        # Check if the request was successful
        response.raise_for_status()
        # Parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        # Find and extract the main body content (you might need to adjust this based on the structure of your HTML)
        main_content = soup.find('<h1>,<h2>,<h3>,<h4>,<h5>,<h6>,<table>,<li>,<p>,<p class>,<p style>,<pre>')
        return main_content
    except requests.exceptions.RequestException as e:
        print(f"Error scraping {url}: {e}")
        return None
    except Exception as e:
        print(f"Unexpected error scraping {url}: {e}")
        return None
# Function to extract content from a PDF and convert it to CSV
def extract_pdf_content(url):
    try:
        # Send a GET request to the PDF URL
        response = requests.get(url)
        # Check if the request was successful
        response.raise_for_status()
        
        # Parse the PDF content
        with io.BytesIO(response.content) as pdf_file:
            pdf_reader = PyPDF2.PdfReader(pdf_file)
            num_pages = len(pdf_reader.pages)
            text = ""
            for page_num in range(num_pages):
                page = pdf_reader.pages[page_num]
                text += page.extract_text()
        
        # For demonstration purposes, let's just return the extracted text
        return text
    except requests.exceptions.RequestException as e:
        print(f"Error downloading PDF from {url}: {e}")
        return None
    except Exception as e:
        print(f"Error extracting content from PDF {url}: {e}")
        return None

# Read the CSV file containing links
input_file = "Information on Canoo ﬁnancial.csv"
output_file = "Information on Canoo ﬁnancial data.csv"
data = pd.read_csv(input_file)

# Create an empty list to store scraped content
scraped_content = []

# Iterate through each link in the CSV file and scrape its content
for link in data['URL']:
    content = scrape_content(link)
    scraped_content.append(content)

# Add the scraped content to the DataFrame
data['Scraped Content'] = scraped_content

# Write the DataFrame with scraped content to a new CSV file
data.to_csv(output_file, index=False)

print("Scraping and saving completed!")
# Out:
# Error scraping https://in.marketscreener.com/quote/stock/CANOO-INC-57291647/news/CANOO-INC-MANAGEMENT-S-DISCUSSION-AND-ANALYSIS-OF-FINANCIAL-CONDITION-AND-RESULTS-OF-OPERATIONS-f-43386654/: 403 Client Error: Forbidden. for url: https://in.marketscreener.com/quote/stock/CANOO-INC-57291647/news/CANOO-INC-MANAGEMENT-S-DISCUSSION-AND-ANALYSIS-OF-FINANCIAL-CONDITION-AND-RESULTS-OF-OPERATIONS-f-43386654/
# Error scraping https://in.investing.com/equities/hennessy-capital-acquisition-corp-financial-summary: 403 Client Error: Forbidden for url: https://in.investing.com/equities/hennessy-capital-acquisition-corp-financial-summary
# Error scraping https://finpedia.co/bin/Canoo%2520Inc./: 404 Client Error: Not Found for url: https://finpedia.co/bin/Canoo%2520Inc./
# Error scraping https://www.wsj.com/market-data/quotes/GOEV/financials: 403 Client Error: Forbidden for url: https://www.wsj.com/market-data/quotes/GOEV/financials
# ...

# %%
#script scraps the collected links to get website date by identifying tags to parsed html text and store it in csv file
import pandas as pd
import requests
from bs4 import BeautifulSoup
import PyPDF2
import io

# Function to scrape content from a URL
def scrape_content(url):
    try:
        # Check if the URL is a PDF
        if url.endswith('.pdf'):
            # Handle PDF content
            return extract_pdf_content(url)
        
        # Send a GET request to the URL
        response = requests.get(url)
        # Check if the request was successful
        response.raise_for_status()
        # Parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        # Find and extract the main body content (you might need to adjust this based on the structure of your HTML)
        main_content = soup.find('<h1>,<h2>,<h3>,<h4>,<h5>,<h6>,<table>,<p>,<p class>,<p style>')
        return main_content
    except requests.exceptions.RequestException as e:
        print(f"Error scraping {url}: {e}")
        return None
    except Exception as e:
        print(f"Unexpected error scraping {url}: {e}")
        return None
# Function to extract content from a PDF and convert it to CSV
def extract_pdf_content(url):
    try:
        # Send a GET request to the PDF URL
        response = requests.get(url)
        # Check if the request was successful
        response.raise_for_status()
        
        # Parse the PDF content
        with io.BytesIO(response.content) as pdf_file:
            pdf_reader = PyPDF2.PdfReader(pdf_file)
            num_pages = len(pdf_reader.pages)
            text = ""
            for page_num in range(num_pages):
                page = pdf_reader.pages[page_num]
                text += page.extract_text()
        
        # For demonstration purposes, let's just return the extracted text
        return text
    except requests.exceptions.RequestException as e:
        print(f"Error downloading PDF from {url}: {e}")
        return None
    except Exception as e:
        print(f"Error extracting content from PDF {url}: {e}")
        return None

# Read the CSV file containing links
input_file = "Key trends in the market.csv"
output_file = "Key trends in the market data.csv"
data = pd.read_csv(input_file)

# Create an empty list to store scraped content
scraped_content = []

# Iterate through each link in the CSV file and scrape its content
for link in data['URL']:
    content = scrape_content(link)
    scraped_content.append(content)

# Add the scraped content to the DataFrame
data['Scraped Content'] = scraped_content

# Write the DataFrame with scraped content to a new CSV file
data.to_csv(output_file, index=False)

print("Scraping and saving completed!")
# Out:
# Error scraping https://www.mikevestil.com/market-trends/: 403 Client Error: Forbidden for url: https://www.mikevestil.com/market-trends/
# Error scraping https://fastercapital.com/startup-topic/trends-and-changes-in-consumer.html: 406 Client Error: Not Acceptable for url: https://fastercapital.com/startup-topic/trends-and-changes-in-consumer.html
# Error scraping https://alistemarketing.com/blog/identifying-trends-in-consumer-buying-behavior-understanding-the-shifting-demands-of-modern-consumers/: 403 Client Error: Forbidden for url: https://alistemarketing.com/blog/identifying-trends-in-consumer-buying-behavior-understanding-the-shifting-demands-of-modern-consumers/
# Error scraping https://growthnatives.com/blogs/digital-marketing/what-are-the-key-marketing-trends/: 403 Client Error: Forbidden for url: https://growthnatives.com/blogs/digital-marketing/what-are-the-key-marketing-trends/
# ...

# %%
# The script uses langchain community pakage pdf loader to load pdf and split into documents for vectorization
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("C:\\Users\\barry\\RAG retrival argumentive generation\\data.pdf")
pages = loader.load_and_split()

# %%
import os
os.environ['OPENAI_API_KEY'] = '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'

# %%
pip install faiss-cpu
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
#   Obtaining dependency information for faiss-cpu from https://files.pythonhosted.org/packages/3e/8f/55f8cd863c678a703aa3b97e5f4511cfd2c52987ba05459afdcdec76eeb3/faiss_cpu-1.7.4-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB 187.9 kB/s eta 0:00:58
#    ---------------------------------------- 0.1/10.8 MB 297.7 kB/s eta 0:00:36
#    ---------------------------------------- 0.1/10.8 MB 374.1 kB/s eta 0:00:29
#    ---------------------------------------- 0.1/10.8 MB 374.1 kB/s eta 0:00:29
#     --------------------------------------- 0.2/10.8 MB 482.7 kB/s eta 0:00:22
# ...

# %%
# using (Facebook AI Similarity Search) on embedded documents indexed on vectorized database print results based on queries
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings

faiss_index = FAISS.from_documents(pages, OpenAIEmbeddings())
docs = faiss_index.similarity_search("Identify the industry in which Canoo operates", k=4)
for doc in docs:
    print(str(doc.metadata["page"]) + ":", doc.page_content[:1900])
# Out:
# 4732: periods.
# 5Table
#  of
# Contents
# PART I
# ITEM 1. BUSINESS
# Company Overview
# Canoo is a high tech advanced mobility technology company with a mission to bring
# electric vehicles (“EVs”) to everyone and provide connected services that improve
# the fleet or individual vehicle ownership experience. We are developing a
# technology platform that we believe will enable us to rapidly innovate, iterate and
# bring new products,
# addressing multiple use cases, to market faster than our competition and at lower
# cost. Our vehicle architecture and design philosophy are aimed at driving
# productivity and
# returning capital to our customers, and we believe the software and technology
# capabilities we are developing, packaged around a modular, customizable product,
# have the potential
# to empower the customer experience across a vehicle’s lifecycle. We remain
# committed to the environment and to delivering sustainable mobility that is
# accessible to everyone. We
# ...
